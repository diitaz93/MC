# %% [markdown]
# #10 - Ecuaciones Diferenciales Ordinarias

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %% [markdown]
# $$ \frac{d}{dt}Y(t) = f(Y) $$

# %%
x_fine=np.linspace(0,1,100)
x_coarse=np.linspace(0,1,10)
plt.figure()
plt.plot(x_fine,np.sin(x_fine))
plt.plot(x_coarse,np.sin(x_coarse),"or")
plt.title(u"Discretización") 
plt.show()

# %% [markdown]
# ## Método de Euler y Regla del Punto Medio

# %% [markdown]
# $$Y(t_{n+1}) \approx Y(t_n) + f(Y(t_n),t_n) \Delta t$$
# $$\textrm{Forward}$$

# %%
def f(z):
    return 1.j*z
def one_Euler_step():
    global t
    global Deltat
    global z
    z+= f(z)*Deltat
    t+=Deltat

# %%
numIters=np.logspace(1,3,20,2)
lastones=[]
plt.figure(figsize=(7,7))
plt.subplot(211)
chosenstep=one_Euler_step
for numIterf in numIters:
    z=1.
    tmax=2*np.pi
    t=0.
    numIter=np.int(numIterf)
    Deltat=tmax/numIter
    history=[[t,z]]
    for __ in range(numIter):
        chosenstep()
        history.append([t,z])
    ahistory=np.array(history)
    lastones.append(history[-1])
    plt.plot(np.real(ahistory[:,1]),np.imag(ahistory[:,1]),label=r"$\Delta t = $"+str(np.round(Deltat,3)))
plt.legend()
plt.title("Euler Method")
plt.axis('equal')
alastones=np.array(lastones)
plt.subplot(212)
plt.plot(tmax/numIters,np.abs(1-alastones[:,1]),"o")
plt.xscale('log')
plt.yscale('log')
plt.show()
np.polyfit(np.log(tmax/numIters),np.log(np.abs(1-alastones[:,1])),1)
# Out:
# array([ 1.16431525,  1.82743101])

# %% [markdown]
# $$Y(t_{n+1}) \approx Y(t_n) + \frac{1}{2}(K_1+K_2)\Delta t$$
# $$ K_1 = f(t_n)$$
# $$ K_2 = f( Y + \frac{df}{dY} * f(t_n) \Delta t$$
# $$\textrm{Midpoint Rule}$$

# %%
def fp(z):
    return 1.j
def one_midpoint_step():
    global t
    global Deltat
    global z
    K1= f(z)
    K2= f(z + f(z)*Deltat) 
    z+= Deltat/2. * (K1+K2)

# %%
numIters=np.logspace(1,3,20,2)
lastones=[]
plt.figure(figsize=(7,7))
plt.subplot(211)
chosenstep=one_midpoint_step
for numIterf in numIters:
    z=1.
    tmax=2*np.pi
    t=0.
    numIter=np.int(numIterf)
    Deltat=tmax/numIter
    history=[[t,z]]
    for __ in range(numIter):
        chosenstep()
        history.append([t,z])
    ahistory=np.array(history)
    lastones.append(history[-1])
    plt.plot(np.real(ahistory[:,1]),np.imag(ahistory[:,1]),label=r"$\Delta t = $"+str(np.round(Deltat,3)))
plt.legend()
plt.title("Midpoint rule")
plt.axis('equal')
alastones2=np.array(lastones)
plt.subplot(212)
plt.plot(tmax/numIters,np.abs(1-alastones2[:,1]),"o")
plt.xscale('log')
plt.yscale('log')
plt.show()
np.polyfit(np.log(tmax/numIters),np.log(np.abs(1-alastones2[:,1])),1)
# Out:
# array([ 2.02114309,  0.13310322])

# %% [markdown]
# ## Runge-Kutta 3er orden

# %%
def one_Kutta3_step():
    global t
    global Deltat
    global z
    K1 = f(z)
    K2 = f(z+Deltat*(1/2.*K1))
    K3 = f(z + Deltat*(-K1+2.*K2))
    z+= Deltat / 6. * (K1+4*K2+K3)

# %%
numIters=np.logspace(1,3,20,2)
lastones=[]
plt.figure(figsize=(7,7))
plt.subplot(211)
chosenstep=one_Kutta3_step
for numIterf in numIters:
    z=1.
    tmax=2*np.pi
    t=0.
    numIter=np.int(numIterf)
    Deltat=tmax/numIter
    history=[[t,z]]
    for __ in range(numIter):
        chosenstep()
        history.append([t,z])
    ahistory=np.array(history)
    lastones.append(history[-1])
    plt.plot(np.real(ahistory[:,1]),np.imag(ahistory[:,1]),label=r"$\Delta t = $"+str(np.round(Deltat,3)))
plt.legend()
plt.title("Kutta Orden 3")
plt.axis('equal')
alastones3=np.array(lastones)
plt.subplot(212)
plt.plot(tmax/numIters,np.abs(1-alastones3[:,1]),"o")
plt.xscale('log')
plt.yscale('log')
plt.show()
np.polyfit(np.log(tmax/numIters),np.log(np.abs(1-alastones3[:,1])),1)
# Out:
# array([ 3.01586309, -1.2685662 ])

# %% [markdown]
# ## Runge-Kutta Orden 4

# %%
def one_Kutta4_step():
    global t
    global Deltat
    global z
    K1 = f(z)
    K2 = f(z + Deltat*(1/2.*K1))
    K3 = f(z + Deltat*(1./2.*K2))
    K4 = f(z + Deltat*K3)
    z+= Deltat * (1/6.*K1 + 1/3. * K2 + 1/3.*K3 + 1/6.*K4)

# %%
numIters=np.logspace(1,3,20,2)
lastones=[]
plt.figure(figsize=(7,7))
plt.subplot(211)
chosenstep=one_Kutta4_step
for numIterf in numIters:
    z=1.
    tmax=2*np.pi
    t=0.
    numIter=np.int(numIterf)
    Deltat=tmax/numIter
    history=[[t,z]]
    for __ in range(numIter):
        chosenstep()
        history.append([t,z])
    ahistory=np.array(history)
    lastones.append(history[-1])
    plt.plot(np.real(ahistory[:,1]),np.imag(ahistory[:,1]),label=r"$\Delta t = $"+str(np.round(Deltat,3)))
plt.legend()
plt.title("Kutta Orden 4")
plt.axis('equal')
alastones4=np.array(lastones)
plt.subplot(212)
plt.plot(tmax/numIters,np.abs(1-alastones4[:,1]),"o")
plt.xscale('log')
plt.yscale('log')
plt.show()
np.polyfit(np.log(tmax/numIters),np.log(np.abs(1-alastones4[:,1])),1)
# Out:
# array([ 4.02526805, -2.8387749 ])

# %%
plt.figure(figsize=(10,5))
plt.plot(tmax/numIters,np.abs(1-alastones4[:,1]),"o--",label="Orden 2")
plt.plot(tmax/numIters,np.abs(1-alastones3[:,1]),"o--",label="Orden 3")
plt.plot(tmax/numIters,np.abs(1-alastones2[:,1]),"o--",label="Orden 4")
plt.xscale('log')
plt.yscale('log')
plt.xlabel('step size') 
plt.ylabel('error')
plt.legend()
plt.show()

# %% [markdown]
# ## El problema de Kepler

# %%
def f(Y):
    r3=(np.sqrt(Y[0]**2+Y[1]**2))**3
    return np.array([Y[2],Y[3],-Y[0]/r3,-Y[1]/r3])

# %%
def one_Kutta4_step():
    global t
    global Deltat
    global Y
    K1 = f(Y)
    K2 = f(Y + Deltat*(1./2.*K1))
    K3 = f(Y + Deltat*(1./2.*K2))
    K4 = f(Y + Deltat*K3)
    Y+= Deltat * (1/6.*K1 + 1/3. * K2 + 1/3.*K3 + 1/6.*K4)
    t+= Deltat

# %%
chosenstep=one_Kutta4_step
numIter=100
Y=np.array([1.,0.,0.,1.])
tmax=2*np.pi
t=0.
Deltat=tmax/numIter
history=np.array([[t,Y[0],Y[1],Y[2],Y[3]]])
for __ in range(numIter):
    chosenstep()
    history=np.append(history,[[t,Y[0],Y[1],Y[2],Y[3]]],axis=0)
plt.figure()
plt.plot(history[:,1],history[:,2],"o",ms=1)
plt.title("Kutta Orden 4")
plt.axis('equal')
plt.show()

# %%
chosenstep=one_Kutta4_step
numIter=3000
vinis=np.linspace(0.4,0.98*np.sqrt(2),10)
plt.figure(figsize=(10,10))
for vini in vinis:
    Y=np.array([1.,0.,0.,vini])
    t=0.
    ecc=np.sqrt(1.+2*vini**2*(0.5*vini**2-1.))
    # am = vini**2/(1-ecc**2) semi eje mayor
    tmax=2*np.pi#2*np.pi*am**(3./2.)*0.5
    Deltat=tmax/numIter
    history=np.array([[t,Y[0],Y[1],Y[2],Y[3]]])
    for __ in range(numIter):
        chosenstep()
        history=np.append(history,[[t,Y[0],Y[1],Y[2],Y[3]]],axis=0)
    plt.plot(history[:,1],history[:,2])
    plt.axis('equal')
    plt.xlim(-2,2)
    plt.ylim(-2,2)
    plt.xlabel("x/UA")
    plt.ylabel("y/UA")
plt.title("El problema de Kepler\n")
plt.plot([0],[0],"oy",ms=5)
plt.show()

# %%
# Tercera ley de Kepler
chosenstep=one_Kutta4_step
numIter=3000
vinis=np.linspace(0.4,1.3,10)
plt.figure(figsize=(10,10))
times=np.array([])
mayors=np.array([])
for vini in vinis:
    Y=np.array([1.,0.,0.,vini])
    t=0.
    ecc=np.sqrt(1.+2*vini**2*(0.5*vini**2-1.))
    am = vini**2/(1-ecc**2) # semi eje mayor
    Deltat=2.*np.pi/numIter
    history=np.array([[t,Y[0],Y[1],Y[2],Y[3]]])
    while Y[1]>=0:
        chosenstep()
        history=np.append(history,[[t,Y[0],Y[1],Y[2],Y[3]]],axis=0)
    times=np.append(times,t)
    mayors=np.append(mayors,(abs(Y[0])+1.)/2.)
    plt.plot(history[:,1],history[:,2])
    plt.axis('equal')
    plt.xlim(-2,2)
    plt.ylim(-2,2)
    plt.xlabel("x/UA")
    plt.ylabel("y/UA") 
plt.plot([0],[0],"oy",ms=5)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(times,mayors,"o")
plt.xscale('log')
plt.yscale('log')
plt.axis('equal')
plt.show()

# %%
np.polyfit(np.log(times),np.log(mayors),1)
# Out:
# array([ 0.66676703, -0.76347726])

# %%
chosenstep=one_Kutta4_step
numIter=3000
vinis=np.linspace(0.4,1.3,10)
plt.figure(figsize=(10,10))

vini=vinis[2]
Y=np.array([1.,0.,0.,vini])
t=0.
ecc=np.sqrt(1.+2*vini**2*(0.5*vini**2-1.))
am = vini**2/(1-ecc**2) # semi eje mayor
Deltat=2.*np.pi/numIter
history=np.array([[t,Y[0],Y[1],Y[2],Y[3]]])
print vini
while t<=2*times[2]:
    chosenstep()
    history=np.append(history,[[t,Y[0],Y[1],Y[2],Y[3]]],axis=0)
times=np.append(times,t)
#mayors=np.append(mayors,(abs(Y[0])+1.)/2.)
plt.plot(history[:,1],history[:,2])
plt.axis('equal')
plt.xlim(-2,2)
plt.ylim(-2,2)
plt.xlabel("x/UA")
plt.ylabel("y/UA") 
#counter+=1
plt.plot([0],[0],"oy",ms=5)
plt.show()
# Out:
# 0.6

# %%
# Primera ley de Kepler
theX=history[:,1]
theY=history[:,2]
theVx=history[:,3]
theVy=history[:,4]
themayor=mayors[2]
tiempos=np.linspace(0,2*times[2],len(theX))
d1 = np.sqrt(theX**2+theY**2)
d2 = np.sqrt((theX-(2.-2.*themayor))**2+theY**2)
plt.figure(figsize=(10,5))
plt.plot(tiempos,d1,label='d1')
plt.plot(tiempos,d2,label='d2')
plt.plot(tiempos,d1+d2,"r",label='d1+d2')
plt.xlim(0,max(tiempos))
plt.legend()
plt.ylabel("d/UA")
plt.xlabel(u"t/año")
plt.show()

# %%
# Segunda ley de Kepler
plt.figure(figsize=(10,5))
plt.plot([0,max(tiempos)],[0,0]) # to eliminate buggy yaxis
plt.plot(tiempos,theX*theVy-theY*theVx,"r",label='Momento Angular')
plt.legend()
plt.show()

# %% [markdown]
# ## Implementación de un Método Adaptativo

# %%
def f(Y):
    return np.array([Y[1],-Y[0]])

# %%
def incrementRK4(f,h):
    global Y
    K1 = f(Y)
    K2 = f(Y + h*(1./2.*K1))
    K3 = f(Y + h*(1./2.*K2))
    K4 = f(Y + h*K3)
    return h*(1/6.*(K1 + 2*K2 + 2*K3 + K4))

# %%
# Timestep Fijo
Y=np.array([1.,0.])
tmax=500.
t=0.
h=0.4
x_fine=np.linspace(0,tmax,2*numIter)
history=np.array([[t,Y[0],Y[1]]])
while t <= tmax:
    Y+=incrementRK4(f,h)
    t+=h
    history=np.append(history,[[t,Y[0],Y[1]]],axis=0)
plt.figure(figsize=(10,4))
#plt.plot(history[:,0],history[:,1],"o",ms=1)
plt.subplot(2,1,1)
plt.title("RK4")
plt.plot(history[:,0],history[:,1]-np.cos(history[:,0]),label="error")
plt.plot(history[:,0],history[:,1])
plt.xlim(0.9*tmax,tmax)
plt.ylim(-1,1)
plt.legend()
plt.subplot(2,1,2)
plt.plot(history[:,0],history[:,1]-np.cos(history[:,0]))
plt.plot(history[:,0],history[:,1])
plt.xlim(0*tmax,0.1*tmax)
plt.ylim(-1,1)
plt.show()

# %%
Y=np.array([1.,0.])
tmax=500.
t=0.
h=0.4
# Reducir locerr hasta que el máximo error global sea satisfecho
locerr=.000009767 # Máximo error local
locerr=.000003326 # Máximo error local
locerr=.000001992 # Máximo error local
globerr=0.1
x_fine=np.linspace(0,tmax,2*numIter)
history=np.array([[t,Y[0],Y[1]]])
err=1.
iterNum=0
while t <= tmax:
    err=1.
    while err>locerr:
        Y1=np.copy(Y)
        Y2=np.copy(Y)
        Y1+=incrementRK4(f,h)
        Y1+=incrementRK4(f,h)
        Y2+=incrementRK4(f,2*h)
        err = np.abs(Y2[0]-Y1[0])/30.
        if err >= locerr: # Si el error estimado es mayor al local, reducir h
            h*=0.95
    Y+=incrementRK4(f,h)
    t+=h
    history=np.append(history,[[t,Y[0],Y[1]]],axis=0)
    iterNum+=1
plt.figure(figsize=(10,4))
plt.subplot(2,1,1)
plt.title("RK4-Adaptativo")
plt.plot(history[:,0],history[:,1]-np.cos(history[:,0]),"r-",label="error")
plt.plot(history[:,0],history[:,1],label="sol")
plt.xlim(0.9*tmax,tmax)
plt.ylim(-1,1)
plt.legend()
plt.subplot(2,1,2)
plt.plot(history[:,0],history[:,1]-np.cos(history[:,0]),"r-",label="error")
plt.plot(history[:,0],history[:,1],label="sol")
plt.legend()
plt.xlim(0*tmax,0.1*tmax)
plt.ylim(-1,1)
plt.show()
print "Iteraciones =",iterNum
print "Error Global <", locerr*iterNum
print "Final h =", h
# Out:
# Iteraciones = 64893
# Error Global < 0.129266856
# Final h = 0.00770508791836

# %% [markdown]
# ## Multistep Methods

# %%
from scipy.special import jv
from scipy.special import jvp

# %%
# Adams-Bashforth order 4, de esta familia son los métodos utilizados por odeint
# to solve the Bessel differential equation for n = 0
def f(Y,t,n):
    return np.array([Y[1],-1./t*Y[1]-(1.-n**2/t**2)*Y[0]])

# %%
# f1 is the current slope,
# f2 it the one before
# and f3 the one before that one.
def increment(f1,f2,f3):
    global h
    return  h/12.*(23*f1-16*f2+5*f3)

# %%
plt.figure(figsize=(10,4))
for n in range(3):
    print "Bessel",n
    numIter=1000
    h=0.01
    Y=np.array([jv(n,h),jvp(n,h)])
    f1 = f(Y,h,n)
    f2 = f1
    f3 = f1
    t=h
    gridSol=np.array([[t,Y[0],Y[1]]])
    x_fine=np.linspace(0,numIter*h,numIter*2)
    
    for __ in range(numIter):
        Y += increment(f1,f2,f3)
        t+=h
        # Actualizar los valores de f1, f2 y f3 para la siguiente iteración
        f1, f2, f3 = f(Y,t,n), f1, f2
        gridSol=np.append(gridSol,[[t,Y[0],Y[1]]],axis=0)
    
    plt.plot(gridSol[:,0],gridSol[:,1],"--",label="sol")
    plt.plot(x_fine,jv(n,x_fine),"k",label="exact ")
    plt.legend()
    #plt.xlim(0,1)
    #plt.ylim(0,2)
plt.show()
# Out:
# Bessel 0
# Bessel
#  1
# Bessel
#  2

# %% [markdown]
# ## odeint

# %%
from scipy.integrate import odeint
from scipy.integrate import ode

# %%
help(odeint)
# Out:
# Help on function odeint in module scipy.integrate.odepack:
#
# odeint(func, y0, t, args=(), Dfun=None, col_deriv=0, full_output=0, ml=None, mu=None, rtol=None, atol=None, tcrit=None, h0=0.0, hmax=0.0, hmin=0.0, ixpr=0, mxstep=0, mxhnil=0, mxordn=12, mxords=5, printmessg=0)
#     Integrate a system of ordinary differential equations.
#
#     Solve a system of ordinary differential equations using lsoda from the
#     FORTRAN library odepack.
#
#     Solves the initial value problem for stiff or non-stiff systems
#     of first order ode-s::
#
#         dy/dt = func(y,t0,...)
#
#     where y can be a vector.
#
#     Parameters
#     ----------
#     func : callable(y, t0, ...)
#         Computes the derivative of y at t0.
#     y0 : array
#         Initial condition on y (can be a vector).
#     t : array
#         A sequence of time points for which to solve for y.  The initial
#         value point should be the first element of this sequence.
#     args : tuple, optional
#         Extra arguments to pass to function.
#     Dfun : callable(y, t0, ...)
#         Gradient (Jacobian) of `func`.
#     col_deriv : bool, optional
#         True if `Dfun` defines derivatives down columns (faster),
#         otherwise `Dfun` should define derivatives across rows.
#     full_output : bool, optional
#         True if to return a dictionary of optional outputs as the second output
#     printmessg : bool, optional
#         Whether to print the convergence message
#
#     Returns
#     -------
#     y : array, shape (len(t), len(y0))
#         Array containing the value of y for each desired time in t,
#         with the initial value `y0` in the first row.
#     infodict : dict, only returned if full_output == True
#         Dictionary containing additional output information
#
#         =======  ============================================================
#         key      meaning
#         =======  ============================================================
#         'hu'     vector of step sizes successfully used for each time step.
#         'tcur'   vector with the value of t reached for each time step.
#                  (will always be at least as large as the input times).
#         'tolsf'  vector of tolerance scale factors, greater than 1.0,
#                  computed when a request for too much accuracy was detected.
#         'tsw'    value of t at the time of the last method switch
#                  (given for each time step)
#         'nst'    cumulative number of time steps
#         'nfe'    cumulative number of function evaluations for each time step
#         'nje'    cumulative number of jacobian evaluations for each time step
#         'nqu'    a vector of method orders for each successful step.
#         'imxer'  index of the component of largest magnitude in the
#                  weighted local error vector (e / ewt) on an error return, -1
#                  otherwise.
#         'lenrw'  the length of the double work array required.
#         'leniw'  the length of integer work array required.
#         'mused'  a vector of method indicators for each successful time step:
#                  1: adams (nonstiff), 2: bdf (stiff)
#         =======  ============================================================
#
#     Other Parameters
#     ----------------
#     ml, mu : int, optional
#         If either of these are not None or non-negative, then the
#         Jacobian is assumed to be banded.  These give the number of
#         lower and upper non-zero diagonals in this banded matrix.
#         For the banded case, `Dfun` should return a matrix whose
#         columns contain the non-zero bands (starting with the
#         lowest diagonal).  Thus, the return matrix from `Dfun` should
#         have shape ``len(y0) * (ml + mu + 1)`` when ``ml >=0`` or ``mu >=0``.
#     rtol, atol : float, optional
#         The input parameters `rtol` and `atol` determine the error
#         control performed by the solver.  The solver will control the
#         vector, e, of estimated local errors in y, according to an
#         inequality of the form ``max-norm of (e / ewt) <= 1``,
#         where ewt is a vector of positive error weights computed as
#         ``ewt = rtol * abs(y) + atol``.
#         rtol and atol can be either vectors the same length as y or scalars.
#         Defaults to 1.49012e-8.
#     tcrit : ndarray, optional
#         Vector of critical points (e.g. singularities) where integration
#         care should be taken.
#     h0 : float, (0: solver-determined), optional
#         The step size to be attempted on the first step.
#     hmax : float, (0: solver-determined), optional
#         The maximum absolute step size allowed.
#     hmin : float, (0: solver-determined), optional
#         The minimum absolute step size allowed.
#     ixpr : bool, optional
#         Whether to generate extra printing at method switches.
#     mxstep : int, (0: solver-determined), optional
#         Maximum number of (internally defined) steps allowed for each
#         integration point in t.
#     mxhnil : int, (0: solver-determined), optional
#         Maximum number of messages printed.
#     mxordn : int, (0: solver-determined), optional
#         Maximum order to be allowed for the non-stiff (Adams) method.
#     mxords : int, (0: solver-determined), optional
#         Maximum order to be allowed for the stiff (BDF) method.
#
#     See Also
#     --------
#     ode : a more object-oriented integrator based on VODE.
#     quad : for finding the area under a curve.

# %%
def fun(Y,t):
    return np.array([Y[1],-Y[0]])

# %%
tmax=500
times=np.linspace(0,tmax,1000)
funsol,others=odeint(fun,[1.,0.],times,full_output=True,printmessg=True)
# Out:
# Integration successful.

# %%
tmax=500
times=np.linspace(0,500,1000)
funsol,others=odeint(fun,[1.,0.],times,full_output=True,printmessg=True)
tmax=500.
plt.figure(figsize=(10,4))
#plt.plot(history[:,0],history[:,1],"o",ms=1)
plt.subplot(2,1,1)
plt.title("odeint")
plt.plot(times,funsol[:,0]-np.cos(times),label="error")
plt.plot(times,funsol[:,0])
plt.xlim(0.9*tmax,tmax)
plt.ylim(-1,1)
plt.legend()
plt.subplot(2,1,2)
plt.plot(times,funsol[:,0]-np.cos(times),label="error")
plt.plot(times,funsol[:,0])
plt.xlim(0*tmax,0.1*tmax)
plt.ylim(-1,1)
plt.show()
# Out:
# Integration successful.

# %% [markdown]
# ## Atractor de Lorentz

# %%
sigma=10.
rho=28.
beta=8./3.
# Las ecuaciones del sistema de Lorentz son no lineales y acopladas.
def fun(Y,t):
    return np.array([sigma*(Y[1]-Y[0]),Y[0]*(rho-Y[2])-Y[1],Y[0]*Y[1]-beta*Y[2]])

# %%
tmax=50
times=np.linspace(0,tmax,10000)
funsol,others=odeint(fun,[1.,0.,1.],times,full_output=True,printmessg=True)
# Out:
# Integration successful.

# %%
plt.figure(figsize=(10,10))
#plt.plot(history[:,0],history[:,1],"o",ms=1)
plt.subplot(1,1,1)
plt.title("odeint")
plt.plot(funsol[:,0],funsol[:,1],label="error")
plt.xlim(-30,30)
plt.ylim(-30,30)
plt.plot(funsol[:,0][0],funsol[:,1][0],"ro")
plt.show()

# %%
np.random.random()
# Out:
# 0.7051343083728965

# %%
plt.figure(figsize=(10,10))
for __ in range(50):
    tmax=50
    times=np.linspace(0,tmax,10000)
    funsol=odeint(fun,[60*(np.random.random()-0.5),60*(np.random.random()-0.5),1.],times)
    #plt.plot(history[:,0],history[:,1],"o",ms=1)
    plt.title("Atractor de Lorenz")
    plt.plot(funsol[:,0],funsol[:,1],label="error")
    plt.xlim(-30,30)
    plt.ylim(-30,30)
    plt.plot(funsol[:,0][0],funsol[:,1][0],"ro")
plt.show()

# %%
for i in range(20):
    if 1. == 1.+10**(-i):
        print "1E-"+str(i)+" is insignificant."
        break
# Out:
# 1E-16 is insignificant.

# %%
epsilon=1e-15
tmax=50
times=np.linspace(0,tmax,10000)
funsol1=odeint(fun,[-30.,-30.,1.+epsilon],times)
funsol2=odeint(fun,[-30.,-30.,1.],times)
plt.figure(figsize=(10,7))
plt.subplot(2,1,1)
plt.plot(times,np.sqrt(np.apply_along_axis(sum,1,funsol1-funsol2)**2))
plt.yscale('log')
plt.xlabel("t")
plt.ylabel(r"$\Delta$")
plt.subplot(2,1,2)
plt.plot(times,funsol1[:,0])
plt.plot(times,funsol2[:,0],"r")
plt.xlabel("t")
plt.show()

# %% [markdown]
# ## Pendulum Phase Portrait

# %% [markdown]
# $H=\frac{p^2}{2}-\cos \theta$
#
# $\frac{\textrm{d}q}{\textrm{d}t} = p,\quad\frac{\textrm{d}p}{\textrm{d}t} = -\sin\theta$

# %%
def pendulum(Y,t):
    return np.array([Y[1],-np.sin(Y[0])])

# %%
times=np.linspace(0.,10.,100)
with plt.xkcd():
    plt.figure(figsize=(16,8))
    for p0 in np.linspace(-4,4,10):
        for q0 in np.linspace(-8,8,20):
            sol=odeint(pendulum,[q0,p0],times)
            plt.plot(sol[:,0],sol[:,1])
            plt.plot([q0],[p0],"o")
    plt.xlim(-8,8)
    plt.ylim(-4,4)
    plt.show()
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['Humor Sans', 'Comic Sans MS', 'StayPuft'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=medium. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
